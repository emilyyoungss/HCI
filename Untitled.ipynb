# %%
# Out:
#   File "<ipython-input-25-cab63661e633>", line 1
#     conda install basemap
#                 ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import matplotlib.cm

from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from matplotlib.colors import Normalize

# %%
fig, ax = plt.subplots(figsize=(10,20))
m = Basemap(resolution='i', # c, l, i, h, f or None
            projection='merc',
            lat_0=-4.27 , lon_0=56.49,
            llcrnrlon=-7.95, llcrnrlat= 54.55, urcrnrlon=-0.41, urcrnrlat=60.78)

# %%
m.drawmapboundary(fill_color='#46bcec')
m.fillcontinents(color='#f2f2f2',lake_color='#46bcec')
m.drawcoastlines()

# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-46-aa08555ad7f9> in <module>()
#       1
#       2
# ----> 3 m.readshapefile('data/uk_postcode_bounds/Areas', 'areas')
#
# ~/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py in readshapefile(self, shapefile, name, drawbounds, zorder, linewidth, color, antialiased, ax, default_encoding)
#    2132         shp.default_encoding = default_encoding
#    2133         if not os.path.exists('%s.shp'%shapefile):
# -> 2134             raise IOError('cannot locate %s.shp'%shapefile)
#    2135         if not os.path.exists('%s.shx'%shapefile):
#    2136             raise IOError('cannot locate %s.shx'%shapefile)
#
# OSError: cannot locate data/uk_postcode_bounds/Areas.shp
